# %%
import sys
sys.path.append('..')
from src.funciones_uso import validar_email

email = input("Ingrese un correo electrónico: ")

if validar_email(email):
    print("El correo electrónico es válido.")
else:
    print("El correo electrónico no es válido.")
