# %%
import sys
sys.path.append('..')
from src.funciones_uso import cifrado_cesar, descifrar_mensaje

mensaje = input("ingrese un mensaje: ")
desplazamiento = int(input("ingrese el desplazamiento: "))

mensaje_cifrado = cifrado_cesar(mensaje, desplazamiento)
print(f"Mensaje cifrado: {mensaje_cifrado}")

mensaje_descifrado = descifrar_mensaje(mensaje_cifrado, desplazamiento)
print(f"Mensaje descifrado: {mensaje_descifrado}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 3
#       1 import sys
#       2 sys.path.append('..')
# ----> 3 from src.funciones_uso import cifrado_cesar, descifrar_mensaje
#       4
#       5 mensaje = input("ingrese un mensaje: ")
#       6 desplazamiento = int(input("ingrese el desplazamiento: "))
#
# ImportError: cannot import name 'descifrar_mensaje' from 'src.funciones_uso' (c:\Users\Usuario\Desktop\Taller Ljes\Practica_2\notebooks\..\src\funciones_uso.py)
