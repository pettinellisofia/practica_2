# %%
import sys
sys.path.append('..')
from src.funciones_uso import sortear_amigo_inv

nombres = input("Ingrese los nombres de los participantes separados por coma (, )")

sortear_amigo_inv(nombres)
# Out:
# Resultados del sorteo de amigo invisible:
# Daniela le regala a Mariana
# Mariana le regala a Carlos
# Carlos le regala a Santiago
# Santiago le regala a Lautaro
# Lautaro le regala a Sofia
# Sofia le regala a Daniela
