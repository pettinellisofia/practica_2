# %%
import sys
sys.path.append('..')
from src.funciones_uso import calcular_costoenvio

peso_ingresado = float(input("Ingrese el peso del paquete en kg: "))
zona_ingresada = input("Ingrese la zona de destino (local/regional/nacional): ")

resultado_costo = calcular_costoenvio(peso_ingresado, zona_ingresada)
print(resultado_costo)
# Out:
# Costo de envío: $2000
