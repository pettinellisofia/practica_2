# %%
import sys
sys.path.append('..')
from src.funciones_uso import filtrar_spoilers

review = """La película sigue a un grupo de astronautas que viajan a Marte 
en una misión de rescate. El capitán Torres lidera al equipo a través 
de tormentas solares y fallos en el sistema de navegación. Al llegar 
a Marte descubren que la base está abandonada y los suministros 
destruidos. Torres decide sacrificar la nave nodriza para salvar 
al equipo y logran volver a la Tierra en una cápsula de emergencia. 
El final revela que Torres sobrevivió gracias a un pasaje secreto."""

spo =input("Ingrese las palabras spoiler separadas por coma seguida de un espacio (, ): ")

result = filtrar_spoilers(review, spo)
print(f"Reseña filtrada: {result}")
# Out:
# Reseña filtrada: La película sigue a un ***** de astronautas que viajan a Marte
# en una misión de *******. El capitán Torres lidera al equipo a través
# de tormentas solares y ****** en el sistema de navegación. Al llegar
# a Marte descubren que la base está abandonada y los suministros
# destruidos. Torres decide sacrificar la nave nodriza para salvar
# al equipo y logran volver a la Tierra en una cápsula de **********.
# El final revela que Torres sobrevivió gracias a un pasaje secreto.
